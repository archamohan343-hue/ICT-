# %% [markdown]
# <a href="https://colab.research.google.com/github/archamohan343-hue/ICT-/blob/main/internshipday1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to the session")
# Out:
# Welcome to the session

# %%
print("hello","how","are","you",sep=("_"))
# Out:
# hello_how_are_you

# %%
name='Archa'
roll_number=25
college_name='Govt College Kariavattom'
print(name,roll_number,college_name)
# Out:
# Archa 25 Govt College Kariavattom

# %%
print(f"I am {name} and roll number is {roll_number}.I am from {college_name}")
# Out:
# I am Archa and roll number is 25.I am from Govt College Kariavattom

# %%
firstname= input("enter your first name")
secondname=input("enter your second name")
print(f"your full name is {firstname} {secondname}")
# Out:
# enter your first namevaiga
# enter your second nameks
# your full name is vaiga  ks

# %%
type(firstname)
# Out:
# str

# %%
income=int(input("enter the income"))
expense=int(input("enter the expense"))
savings=income-expense
print(f"savings is {savings}")
# Out:
# enter the income1000
# enter the expense500
# savings is 500

# %%
a=10
b=8
a+b
b-a
# Out:
# -11

# %%
a*b
# Out:
# 570

# %%
a/b
# Out:
# 1.5789473684210527

# %%
a%b
# Out:
# 11

# %%
a**b
# Out:
# 11622614670000000000000000000

# %%
a//b
# Out:
# 1

# %%
print(a>b)
# Out:
# True

# %%
print(a<b)
# Out:
# False

# %%
print(a==b)
# Out:
# False

# %%
print(a!=b)
# Out:
# True

# %%
print(a>2 and b>3)
# Out:
# True

# %%
print(a>2 or b>20)
# Out:
# True

# %%
groceries=['milk','bread','eggs']
print(groceries)
# Out:
# ['milk', 'bread', 'eggs']

# %%
print("length of list is:",len(groceries))
# Out:
# length of list is: 3

# %%
groceries.append("apple")
print(groceries)
# Out:
# ['milk', 'bread', 'eggs', 'apple']

# %%
groceries[0]
# Out:
# 'milk'

# %%
groceries.count('eggs')
# Out:
# 1

# %%
groceries.insert(1,'chocolate')
print(groceries)
# Out:
# ['milk', 'chocolate', 'bread', 'eggs', 'apple']

# %%
groceries.pop(4)
print(groceries)
# Out:
# ['milk', 'chocolate', 'bread', 'eggs']

# %%
groceries.remove("eggs")
print(groceries)
# Out:
# ['milk', 'chocolate', 'bread']

# %%
groceries.sort(reverse=True)
print(groceries)
# Out:
# ['milk', 'chocolate', 'bread']

# %%
str1="Feel free to take any seat that is empty"
print(len(str1))
# Out:
# 40

# %%
str1.upper()
str1.lower()
# Out:
# 'feel free to take any seat that is empty'

# %%
str1.split()
# Out:
# ['Feel', 'free', 'to', 'take', 'any', 'seat', 'that', 'is', 'empty']

# %%
str1.find("is")
# Out:
# 32

# %%
str1[4:]
# Out:
# ' free to take any seat that is empty'

# %%
str1[1:12:3]
# Out:
# 'e et'

# %%
str1[:9]
# Out:
# 'Feel free'

# %%
groceries_2=('milk','bread','eggs')
groceries_2
# Out:
# ('milk', 'bread', 'eggs')

# %%
groceries_3=list(groceries_2)
groceries_3
# Out:
# ['milk', 'bread', 'eggs']

# %%
details={
    "name":"Archa",
    "roll_no":"25",
    "collegename":"gck",
    "blood_group":"A+ve"
}
details
# Out:
# {'name': 'Archa', 'roll_no': '25', 'collegename': 'gck', 'blood_group': 'A+ve'}

# %%
details["name"]
details.get("name")
# Out:
# 'Archa'

# %%
details.keys()
# Out:
# dict_keys(['name', 'roll_no', 'collegename', 'blood_group'])

# %%
details.values()
# Out:
# dict_values(['Archa', '25', 'gck', 'A+ve'])

# %%
details["collegename"]="govt college kariavattom"
details
# Out:
# {'name': 'Archa',
#  'roll_no': '25',
#  'collegename': 'govt college kariavattom',
#  'blood_group': 'A+ve'}

# %%
details["occupation"]="student"
details
# Out:
# {'name': 'Archa',
#  'roll_no': '25',
#  'collegename': 'govt college kariavattom',
#  'blood_group': 'A+ve',
#  'occupation': 'student'}

# %%
details.pop("collegename")
details
# Out:
# {'name': 'Archa',
#  'roll_no': '25',
#  'blood_group': 'A+ve',
#  'occupation': 'student'}

# %%
a=100
b=300

if a>b:
  print("a is greater")
else:
    print("b is greater")
# Out:
# b is greater

# %%
score=90

if score>=90 :
  print("Grade A")
elif score>=80 :
  print("Grade B")
elif score>=70 :
  print("Grade C")
elif score>=60 :
  print("Grade D")
else:
  print("you have failed")
# Out:
# Grade A

# %%
traffic_light="blue"

if traffic_light=="red" :
  print("STOP")
elif traffic_light=="green" :
  print("GO")
elif traffic_light=="yellow" :
  print("WAIT")
else :
  print("traffic signal is not working")
# Out:
# traffic signal is not working

# %%
Bill_amount=int(input("enter your bill amount"))

if Bill_amount>2999 :
  finalbill_amount=Bill_amount-500
  print(finalbill_amount)
elif Bill_amount>1999 :
  finalbill_amount=Bill_amount-250
  print(finalbill_amount)
elif Bill_amount>750 :
  finalbill_amount= Bill_amount-(Bill_amount*(10/100))
  print(finalbill_amount)
else :
  print("No discount avilable")
# Out:
# enter your bill amount800
# 80.0
